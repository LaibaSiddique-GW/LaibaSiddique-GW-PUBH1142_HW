# %% [markdown]
# # Week 10: Data Visualization HW

# %% [markdown]
# > Laiba Siddique

# %% [markdown]
# ## Tasks

# %% [markdown]
# ### Task 1: Create a scatter plot to visualize the correlation between the `platelets` and `serum_sodium` variables, colored by the unique elements (classes or levels) of the `diabetes` variable. Add an appropriate title and axes labels.

# %%
sns.scatterplot(
    data=df,
    x='platelets',
    y='serum_sodium',
    hue='diabetes'
).set(
    title='Platelets and serum sodium',
    xlabel='Platelets [platelets/mL]',
    ylabel='Serum sodium [mEq/L]'
);

# %% [markdown]
# ### Task 2: Generate a histogram to visualize the distribution of the `platelets` variable. Calculate the minimum and the maximum value for the variable and use the `range` function to create a intervals of $50000$. Note that the ticks value on the horizontal axis seems *overcrowded*. Try to use the argument `y` instead of `x`. This will create a horizontal histogram, with more space for the tick values.

# %%
df.platelets.min()

df.platelets.max()

sns.displot(
    df,
    y='platelets',
    bins=range(0, 850000,50000)
).set(
    title='Platelet distribution',
    ylabel='Platelets [platelets/mL]',
    xlabel='Frequency'
);

# %% [markdown]
# ### Task 3: Another categorical variable can be added using the `hue` argument and setting a categorical variable as argument. Create a bar plot using the `diabetes` variable as in the figure above, but add the `death` variable as well.

# %%
sns.catplot(
    data=df,
    x='diabetes',
    hue='death',
    kind='count'
);

# %% [markdown]
# ## Questions

# %% [markdown]
# ### Question 1: How do you import the Seaborn package in Python?

# %% [markdown]
# See below. The `as sns` part is not required for importing seaborn, though it makes working with it easier.

# %%
import seaborn as sns

# Import other libraries
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# The `config` magic command is used to set high resolution figures.

# %%
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# I will use the same style as the notes. However, my VSCode is in Dark Mode.

# %%
sns.set_style(style='whitegrid')

# %% [markdown]
# ### Question 2: How do you create a scatter plot in Seaborn for variables `x` and `y` in a DataFrame `df`?

# %% [markdown]
# See below, underneath the csv import cell. The answer is commented out, so the output shows some other variable within my dataset instead (since it does not have the specified columms).

# %%
# Import csv file to use in this homework
df = pd.read_csv('https://raw.githubusercontent.com/juanklopper/TutorialData/main/heart_failure.csv')

# %%
# sns.scatterplot(
#     data=df,
#     x='x',
#     y='y'
# );
sns.scatterplot(
    data=df,
    x='age',
    y='platelets'
);

# %% [markdown]
# ### Question 3: How do you create a line plot in Seaborn for variables `x` and `y` in a DataFrame `df`?

# %% [markdown]
# Use the `lineplot` function.
# See below. The answer is commented out, so the output shows some other variable within my dataset instead (since it does not have the specified columms).

# %%
# sns.lineplot(
#     data=df,
#     x="x", 
#     y="y"
# );
sns.lineplot(
    data=df,
    x="serum_creatinine", 
    y="platelets"
);

# %% [markdown]
# ### Question 4: How do you create a histogram in Seaborn for a variable `x` in a DataFrame `df`?

# %% [markdown]
# The `displot` function can produce a histogram.
# See below. The answer is commented out, so the output shows some other variable within my dataset instead (since it does not have the specified columms).

# %%
# sns.displot(
#     df,
#     x='x'
# ).set(
#     title='x distribution',
#     xlabel='x label',
#     ylabel='x frequency'
# );
sns.displot(
    df,
    x='age'
).set(
    title='Age distribution',
    xlabel='Age [years]',
    ylabel='Frequency'
);

# %% [markdown]
# ### Question 5: How do you create a stacked histogram in Seaborn for variables `x` and 'hue' `y` in a DataFrame df?

# %% [markdown]
# The `multiple` argument in the `displot` function is set to `'stack'` to produce a stacked histogram. The `bins` argument is not necesary based on the question instructions, though specifiying bins can help visualize the data better.
# See below. The answer is commented out, so the output shows some other variable within my dataset instead (since it does not have the specified columms).

# %%
# sns.displot(
#     df,
#     x='x',
#     bins=range(40, 110, 10),
#     hue='y',
#     multiple='stack'
# ).set(
#     title='Age distribution',
#     xlabel='Age [years]',
#     ylabel='Frequency'
# );
sns.displot(
    df,
    x='age',
    bins=range(40, 110, 10),
    hue='anaemia',
    multiple='stack'
).set(
    title='Age distribution',
    xlabel='Age [years]',
    ylabel='Frequency'
);

# %% [markdown]
# ### Question 6: How do you create a heatmap in Seaborn for a variable `x` and `y` in a DataFrame `df`?

# %% [markdown]
# Heat maps can be used to visualize the distribution of two continuous variables. A `y` argument is added to the `displot` function to visualize bivariate distributions. The `cbar` argument adds a color bar.
# See below. The answer is commented out, so the output shows some other variable within my dataset instead (since it does not have the specified columms).

# %%
# sns.displot(
#     df,
#     x='x',
#     y='y',
#     cbar=True
# ).set(
#     title='x and y',
#     xlabel='x is x',
#     ylabel='y is y'
# );
sns.displot(
    df,
    x='age',
    y='platelets',
    cbar=True
).set(
    title='Age and Platelets',
    xlabel='Age [years]',
    ylabel='Platelets [platelets/mL]'
);

# %% [markdown]
# ### Question 7: How do you create a box plot in Seaborn for variables `x` and `y` in a DataFrame `df`?

# %% [markdown]
# The `catplot` function is used for a variety of plots for categorical data. The `kind` argument is set to `'box'`, to indicate a box-and-whisker plot.
# See below. The answer is commented out, so the output shows some other variable within my dataset instead (since it does not have the specified columms).

# %%
# sns.catplot(
#     data=df,
#     x='x',
#     y='y',
#     kind='box'
# ).set(
#     title='x and y',
#     xlabel='x is x',
#     ylabel='y is y'
# );
sns.catplot(
    data=df,
    x='diabetes',
    y='age',
    kind='box'
).set(
    title='Age and Diabetes',
    xlabel='Diabetes',
    ylabel='Age [years]'
);

# %% [markdown]
# ### Question 8: How do you create a violin plot in Seaborn for variables `x` and `y` in a DataFrame `df`?

# %% [markdown]
# Use the `catplot` method, setting the `kind` argument to `'violin'`.
# See below. The answer is commented out, so the output shows some other variable within my dataset instead (since it does not have the specified columms).

# %%
# sns.catplot(
#     data=df,
#     x='x',
#     y='y',
#     kind='violin'
# ).set(
#     title='x and y',
#     xlabel='x is x',
#     ylabel='y is y'
# );
sns.catplot(
    data=df,
    x='diabetes',
    y='age',
    # hue='death', // removed this to simplify the plot
    kind='violin'
).set(
    title='Age and Diabetes by Survival Group',
    xlabel='Diabetes',
    ylabel='Age [years]'
);

# %% [markdown]
# ### Question 9: How do you create a bar plot in Seaborn for variables `x` and `y` in a DataFrame `df`?

# %% [markdown]
# Use the `catplot` method, setting the `kind` argument to `'count'`. To display `y` alongside `x`, use `hue = 'y'`.
# See below. The answer is commented out, so the output shows some other variable within my dataset instead (since it does not have the specified columms).

# %%
# sns.catplot(
#     data=df,
#     x='x',
#     hue = 'y',
#     kind='count'
# ).set(
#     title='x by y',
#     xlabel='x',
#     ylabel='y'
# );
sns.catplot(
    data=df,
    x='diabetes',
    hue='death',
    kind='count'
).set(
    title='Diabetes by Survival Group',
    xlabel='Diabetes',
    ylabel='Frequency'
);

# %% [markdown]
# ### Question 10: How do you add a title to a Seaborn plot assigned to the variable `ax` with the title 'My Title'?

# %% [markdown]
# The `set` method is used to set the title and axes labels of the plot using the `title`, `xlabel`, and `ylabel` arguments.
# See below. The answer is commented out, so the output shows some other variable within my dataset instead (since it does not have the specified columms).

# %%
# ax = sns.scatterplot(
#     data=df,
#     x='x',
#     y='y'
# )
# ax.set(title='My Title');

ax = sns.scatterplot(
    data=df,
    x='age',
    y='platelets'
)
ax.set(title='My Title');
# ax.set_title('My Title'); This also works.

# %% [markdown]
# ### Question 11: How do you save a Seaborn plot `ax` to a file named 'output.png'?

# %% [markdown]
# See below. Use `get_figure().savefig('OUTPUT_FILE_NAME.png')` on `ax`.

# %%
# I am using the same `ax` plot from the previous question. 
ax.get_figure().savefig('output.png');

# %% [markdown]
# ### Question 12: How do you set the `x` and `y` axis labels to 'X Label' and 'Y Label' respectively for a Seaborn plot `ax`?

# %% [markdown]
# The `set` method is used to set the title and axes labels of the plot using the `title`, `xlabel`, and `ylabel` arguments.
# See below. The answer is commented out, so the output shows some other variable within my dataset instead (since it does not have the specified columms).

# %%
ax.set(
    xlabel='X label', 
    ylabel=' Y label'
);

# The following also works. 
# ax.set_xlabel('X label');
# ax.set_ylabel('Y label');

# plot the ax plot again to show the new labels
ax.get_figure()

# %% [markdown]
# ### Question 13: How do you change the color palette of a Seaborn plot to 'Blues'?

# %% [markdown]
# Use the `set_palette` function, entering a valid color palette name as an argument.
# See below. The answer is commented out, so the output shows some other variable within my dataset instead (since it does not have the specified columms).

# %%
# change the color palette of a Seaborn plot to 'Blues'
sns.set_palette('Blues');

# plot any plot again to show the color pallete change. 
sns.scatterplot(
    data=df,
    x='age',
    y='platelets'
);

# %% [markdown]
# ### Question 14: How do you display a Seaborn plot with a logarithmic scale on the y-axis?

# %% [markdown]
# Use the `set` function with argument `yscale = 'log'`.
# See below. The answer is commented out, so the output shows some other variable within my dataset instead (since it does not have the specified columms).

# %%
# display a Seaborn plot with a logarithmic scale on the y-axis
sns.scatterplot(
    data=df,
    x='age',
    y='platelets'
).set(
    yscale='log'
);

# %% [markdown]
# ### Question 15: How do you add a regression line to a scatter plot in Seaborn for variables `x` and `y` in a DataFrame `df`?

# %% [markdown]
# The `regplot()` function plots both the scatter points and the regression line (with a 95% confidence interval by default).
# See below. The answer is commented out, so the output shows some other variable within my dataset instead (since it does not have the specified columms).

# %%
# set the color pallete to somthing darker so the plot is easier to see. 
sns.set_palette('colorblind');

# sns.regplot(
#     data=df,
#     x='x',
    # y='y'
# );
sns.regplot(
    data=df,
    x='age',
    y='platelets'
);
