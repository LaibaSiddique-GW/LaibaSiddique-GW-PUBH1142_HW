# %% [markdown]
# # Week 6: Intro to Python

# %% [markdown]
# ## Tasks (which require answers)

# %% [markdown]
# ### Task 1: Calculate a solution to the expression below.

# %% [markdown]
# $\frac{(6 + 4) * 2}{10}$

# %%
((6 + 4) * 2) / 10
# Out:
# 2.0

# %% [markdown]
# ### Task 2: Create code such that `x = 5` and `y = x`. Then let `x = 7`. Determine the value of y.

# %% [markdown]
# **y would equal 5** because it was assigned to the *current* value of x at the time of the assignemnt, where x equaled 5, and even if x changes later, y does not change with it.

# %%
x = 5
y = x
x = 7

# %%
y
# Out:
# 5

# %% [markdown]
# ### Task 3: Generate a for loop that prints the square of each integer from `0` to `5` to the screen. Remember to use the `**` symbols for calculating a power, and remember that the last value is not included.

# %%
for i in range(6):
    print(i ** 2)
# Out:
# 0
# 1
# 4
# 9
# 16
# 25

# %% [markdown]
# ### Task 4: Initialize the variable `i` by assigning it the value `0`. This overwrites the current value stored in `i` as used above. Print the square of each 1-unit increment in `i`, while `i` remains less than `10`.

# %%
i = 0
while i < 10:
    print(i ** 2)
    i += 1
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81

# %% [markdown]
# ## Questions

# %% [markdown]
# ### Question 1. Use Python to calculate solutions to the following expressions.

# %% [markdown]
# $3+8$

# %%
3 + 8
# Out:
# 11

# %% [markdown]
# $\frac{33 + 7}{5}$

# %%
(33 + 7) / 5
# Out:
# 8.0

# %% [markdown]
# ### Question 2: Determine the data type of the output of the code`1+2.`and`1+2`. Explain why the data types are different.

# %% [markdown]
# `1 + 2.` will output `3.0`, a floating point number data-typed variable. This is because the `.` in the equation specifies to Python that the number `2` should be casted into a float, and hence the answer, should be casted into a float since at least 1 input is a float. `1 + 2` will output `3`, an integer data typed value since both inputs, and the default output for `1 + 2`, are integers.

# %%
1 + 2.
# Out:
# 3.0

# %%
1 + 2
# Out:
# 3

# %% [markdown]
# ### Question 3: Generate a loop that prints $n^2$ for each of the numbers $n=\{1,2,3,4,5\}$.

# %%
for i in range(1,6):
    print(i ** 2)
# Out:
# 1
# 4
# 9
# 16
# 25

# %% [markdown]
# ### Question 4: Create the variable `i` by assigning the value `1` to it. Create a loop that prints the value of $i^2$ to the screen. Increment the value of `i` by `1` until the value of $i^2$ exceeds `1000`. Print the value assigned to `i` after the loop has completed. Explain why the solution is `i=32`, where $32^2$ is larger than `1000`.

# %%
i = 1
while ((i ** 2) <= 1000):
    print(i ** 2)
    i += 1

print("\ni = " + str(i))
# print(i)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100
# 121
# 144
# 169
# 196
# 225
# 256
# 289
# 324
# 361
# 400
# 441
# 484
# 529
# 576
# 625
# 676
# 729
# 784
# 841
# 900
# 961
#
# i = 32

# %% [markdown]
# The solution is 32 because 32^1 is 921, which is less than 1000, so the loop kept executing.  While 31^2 is 1000, which is greater than 1000, so the loop did not continue to execute at this point. Therefore, the final value of i is 32.
